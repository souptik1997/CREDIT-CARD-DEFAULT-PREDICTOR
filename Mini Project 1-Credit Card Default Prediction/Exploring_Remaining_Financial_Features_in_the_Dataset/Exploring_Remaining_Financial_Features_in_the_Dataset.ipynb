# %% [markdown]
# **Run the two cells below before you begin. These will set the notebook to autosave every 10 seconds, import the necessary libraries for this challenge, and set figure appearance.**

# %%
# %autosave 10
# Out:
# Autosaving every 10 seconds

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
# %matplotlib inline

mpl.rcParams['figure.dpi'] = 400
mpl.rcParams['font.size'] = 4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **To begin, import data set `cleaned_data.csv` and create lists of feature names for the remaining financial features: `'BILL_AMT1'`, `'BILL_AMT2'`, `'BILL_AMT3'`, `'BILL_AMT4'`, `'BILL_AMT5'`, `'BILL_AMT6'`,  `'PAY_AMT1'`, `'PAY_AMT2'`, `'PAY_AMT3'`, `'PAY_AMT4'`, `'PAY_AMT5'`, and `'PAY_AMT6'`.**
#
# **Name the features `bill_feats` and `pay_amt_feats`, respectively.**

# %%
df = pd.read_csv("cleaned_data.csv")
df.head(5)
# Out:
#               ID  LIMIT_BAL  SEX  ...  high school  others  university
# 0  798fc410-45c1      20000    2  ...            0       0           1
# 1  8a8c8f3b-8eb4     120000    2  ...            0       0           1
# 2  85698822-43f5      90000    2  ...            0       0           1
# 3  0737c11b-be42      50000    2  ...            0       0           1
# 4  3b7f77cc-dbc0      50000    1  ...            0       0           1
#
# [5 rows x 30 columns]

# %%
bill_feats=[]
pay_amt_feats=[]
bill_feats=df[['BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6']]
pay_amt_feats=df[['PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']]
pay_amt_feats
# Out:
#        PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0             0       689         0         0         0         0
# 1             0      1000      1000      1000         0      2000
# 2          1518      1500      1000      1000      1000      5000
# 3          2000      2019      1200      1100      1069      1000
# 4          2000     36681     10000      9000       689       679
# ...         ...       ...       ...       ...       ...       ...
# 26659      8500     20000      5003      3047      5000      1000
# 26660      1837      3526      8998       129         0         0
# 26661         0         0     22000      4200      2000      3100
# 26662     85900      3409      1178      1926     52964      1804
# 26663      2078      1800      1430      1000      1000      1000
#
# [26664 rows x 6 columns]

# %% [markdown]
# ____________________________________________________________________________________
# **Next, use `.describe()` to examine statistical summaries of the bill amount features**

# %%
bill_feats.describe()
# Out:
#            BILL_AMT1      BILL_AMT2  ...      BILL_AMT5      BILL_AMT6
# count   26664.000000   26664.000000  ...   26664.000000   26664.000000
# mean    51405.730723   49300.001500  ...   40338.136701   38889.872337
# std     73633.687106   70934.549534  ...   60705.944083   59432.541657
# min   -165580.000000  -69777.000000  ...  -81334.000000 -339603.000000
# 25%      3580.000000    2999.750000  ...    1745.000000    1256.000000
# 50%     22361.000000   21150.000000  ...   18066.000000   17005.000000
# 75%     67649.750000   64395.500000  ...   50290.500000   49253.750000
# max    746814.000000  671563.000000  ...  823540.000000  699944.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# Reflect on what you see. Does it make sense?

# %% [markdown]
# ___________________________________________________________________________________
# **Then you should visualize the bill amount features using a 2 by 3 grid of histogram plots.**
# > Hint: You can use 20 bins for this visualization.

# %%
bill_feats.hist(bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f300b755e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f300b2bb400>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3009a67668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3009a1a8d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f30099ceb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3009a02da0>]],
#       dtype=object)

# %% [markdown]
# ________________________________________________________________________
# **Next, obtain the `.describe()` summary of the payment amount features.**

# %%
pay_amt_feats.describe()
# Out:
#             PAY_AMT1      PAY_AMT2  ...       PAY_AMT5       PAY_AMT6
# count   26664.000000  2.666400e+04  ...   26664.000000   26664.000000
# mean     5704.085771  5.881110e+03  ...    4843.729973    5257.843047
# std     16699.398632  2.121431e+04  ...   15311.721795   17635.468185
# min         0.000000  0.000000e+00  ...       0.000000       0.000000
# 25%      1000.000000  8.020000e+02  ...     242.750000     111.000000
# 50%      2114.500000  2.007000e+03  ...    1500.000000    1500.000000
# 75%      5027.000000  5.000000e+03  ...    4082.750000    4015.000000
# max    873552.000000  1.227082e+06  ...  426529.000000  528666.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# [link text](https:// [link text](https://))    Does this make sense?

# %% [markdown]
# _______________________________________________________________________________________
# **Next, plot a histogram of the bill payment features similar to the bill amount features,
# but also apply some rotation to the x-axis labels with the `xrot` keyword argument
# so that they don't overlap. In any plotting function, you can include the `xrot=<angle>`
# keyword argument to rotate x-axis labels by a given angle in degrees.**

# %%
pay_amt_feats.hist(xrot=180
                   )
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3008ca0940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3008d83828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3008c75208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3008c27588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3008bd8908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3008b8ac88>]],
#       dtype=object)

# %% [markdown]
#     Consider these results.

# %% [markdown]
# ______________________________________________________________________________________________
# **Then, use a Boolean mask to see how many of the payment amount data are exactly equal to 0. Review the results of the generated mask using `.head()` and `.sum()`.**

# %%
pay_amt_mask=pay_amt_feats==0

# %%
pay_amt_mask.head()
# Out:
#    PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6
# 0      True     False      True      True      True      True
# 1      True     False     False     False      True     False
# 2     False     False     False     False     False     False
# 3     False     False     False     False     False     False
# 4     False     False     False     False     False     False

# %%
pay_amt_mask.sum()
# Out:
# PAY_AMT1    4656
# PAY_AMT2    4833
# PAY_AMT3    5293
# PAY_AMT4    5697
# PAY_AMT5    5981
# PAY_AMT6    6373
# dtype: int64

# %% [markdown]
#      Does this make sense given the histogram in the previous step?

# %% [markdown]
# _______________________________________________________________________________________________________________________________
# **Finally, ignoring the payments of 0 using the mask you created in the previous step, use pandas `.apply()` and NumPy's `np.log10()` to plot histograms of logarithmic transformations of the non-zero payments.**
# > Hint: You can use `.apply()` to apply any function, including `log10`, to all the elements of a DataFrame or a column using the following syntax: `.apply(<function_name>)`.

# %%
inverted_mask = pay_amt_mask ==False
df2=pay_amt_feats[inverted_mask]
np.log(df2).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3008fa6f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30090269e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3008f455c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3008a30e48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f30074ed128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f300749d390>]],
#       dtype=object)
